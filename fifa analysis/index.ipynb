# %% [markdown]
# ## fifa world cup analysis to determine which team will win the group stages, round of 16, quarter finals, semi finals and finals respectively

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib_inline as plt

# %%
groups = pd.read_csv('Fifa_Worldcup_2022_Groups.csv')
matches = pd.read_csv('international_matches.csv')
player_ratings = pd.read_csv('FIFA22_official_data.csv')
player_ratings
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %%
groups['Group'] = groups['Group'].replace(['A1','A2','A3','A4'],"A")
groups['Group'] = groups['Group'].replace(['B1','B2','B3','B4'],"B")
groups['Group'] = groups['Group'].replace(['C1','C2','C3','C4'],"C")
groups['Group'] = groups['Group'].replace(['D1','D2','D3','D4'],"D")
groups['Group'] = groups['Group'].replace(['E1','E2','E3','E4'],"E")
groups['Group'] = groups['Group'].replace(['F1','F2','F3','F4'],"F")
groups['Group'] = groups['Group'].replace(['G1','G2','G3','G4'],"G")
groups['Group'] = groups['Group'].replace(['H1','H2','H3','H4'],"H")
groups.head()
# Out:
#   Group                                         Flag_Image Country_Name  \
# 0     A  https://cloudinary.fifa.com/api/v3/picture/fla...        Qatar
# 1     A  https://cloudinary.fifa.com/api/v3/picture/fla...      Ecuador
# 2     A  https://cloudinary.fifa.com/api/v3/picture/fla...      Senegal
# 3     A  https://cloudinary.fifa.com/api/v3/picture/fla...  Netherlands
# 4     B  https://cloudinary.fifa.com/api/v3/picture/fla...      England
#
#   Country_Name_Short
# 0                QAT
# 1                ECU
# 2                SEN
# 3                NED
# 4                ENG

# %%
groups.drop(columns=['Flag_Image'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\MUNGAI\Downloads\fifa analysis\index.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MUNGAI/Downloads/fifa%20analysis/index.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> groups.drop(columns=['Flag_Image'], inplace = True)
#       <a href='vscode-notebook-cell:/c%3A/Users/MUNGAI/Downloads/fifa%20analysis/index.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> groups = groups.transpose()
#
# File c:\Users\MUNGAI\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
groups_1 = groups.transpose()
groups_1
# Out:
#                        0        1        2            3        4        5   \
# Group                   A        A        A            A        B        B
# Country_Name        Qatar  Ecuador  Senegal  Netherlands  England  IR Iran
# Country_Name_Short    QAT      ECU      SEN          NED      ENG      IRN
#
#                      6      7          8             9   ...       22  \
# Group                 B      B          C             C  ...        F
# Country_Name        USA  Wales  Argentina  Saudi Arabia  ...  Morocco
# Country_Name_Short  USA    WAL        ARG           KSA  ...      MAR
#
#                          23      24      25           26        27        28  \
# Group                     F       G       G            G         G         H
# Country_Name        Croatia  Brazil  Serbia  Switzerland  Cameroon  Portugal
# Country_Name_Short      CRO     BRA     SRB          SUI       CMR       POR
#
#                        29       30              31
# ...

# %%
# def grouping(df,col,group):
#     df.loc[df[col]== group]

#     return df.loc[df[col]== group]

def grouping(col):
    df = groups.loc[groups['Group']== col]
    
    return df

# %%
# A function to create columns of the group names
def group_name(col):
    groups[col] = groups.loc[groups['Group']== col, 'Country_Name']
    
    return groups

# %%
group = ["A","B",'C','D','E','F','G','H']

for i in group:
    group_name(i)

groups
# Out:
#    Group                                         Flag_Image    Country_Name  \
# 0      A  https://cloudinary.fifa.com/api/v3/picture/fla...           Qatar
# 1      A  https://cloudinary.fifa.com/api/v3/picture/fla...         Ecuador
# 2      A  https://cloudinary.fifa.com/api/v3/picture/fla...         Senegal
# 3      A  https://cloudinary.fifa.com/api/v3/picture/fla...     Netherlands
# 4      B  https://cloudinary.fifa.com/api/v3/picture/fla...         England
# 5      B  https://cloudinary.fifa.com/api/v3/picture/fla...         IR Iran
# 6      B  https://cloudinary.fifa.com/api/v3/picture/fla...             USA
# 7      B  https://cloudinary.fifa.com/api/v3/picture/fla...           Wales
# 8      C  https://cloudinary.fifa.com/api/v3/picture/fla...       Argentina
# 9      C  https://cloudinary.fifa.com/api/v3/picture/fla...    Saudi Arabia
# 10     C  https://cloudinary.fifa.com/api/v3/picture/fla...          Mexico
# ...

# %%
groups
# Out:
#    Group                                         Flag_Image    Country_Name  \
# 0      A  https://cloudinary.fifa.com/api/v3/picture/fla...           Qatar
# 1      A  https://cloudinary.fifa.com/api/v3/picture/fla...         Ecuador
# 2      A  https://cloudinary.fifa.com/api/v3/picture/fla...         Senegal
# 3      A  https://cloudinary.fifa.com/api/v3/picture/fla...     Netherlands
# 4      B  https://cloudinary.fifa.com/api/v3/picture/fla...         England
# 5      B  https://cloudinary.fifa.com/api/v3/picture/fla...         IR Iran
# 6      B  https://cloudinary.fifa.com/api/v3/picture/fla...             USA
# 7      B  https://cloudinary.fifa.com/api/v3/picture/fla...           Wales
# 8      C  https://cloudinary.fifa.com/api/v3/picture/fla...       Argentina
# 9      C  https://cloudinary.fifa.com/api/v3/picture/fla...    Saudi Arabia
# 10     C  https://cloudinary.fifa.com/api/v3/picture/fla...          Mexico
# ...

# %%
fifa_groups.drop(columns=['Group', 'Country_Name'], axis=1, inplace = True)

# %%
fifa_groups['B'] = fifa_groups['B'].dropna(inplace=True)
fifa_groups['B']
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# Name: B, dtype: object

# %%
matches
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
# write a function to get players according their nationality

def team(nationality):
    df = player_ratings[player_ratings['Nationality'] == nationality].sort_values(by = ['Best Overall Rating'], ascending= False)

    return df

# %%
# loop through all the nationalities to get each team
nationalities = [groups['Country_Name']]

for nation in nationalities:
# Out:
#   Input In [29]
#
#     ^
# IndentationError: expected an indented block

# %%
Argentina = team('Argentina')
# Out:
#            ID           Name  Age  \
# 29     158023       L. Messi   34
# 156    211110      P. Dybala   27
# 128    231478    L. Martínez   23
# 76     183898    A. Di María   33
# 396    153079      S. Agüero   33
# 173    214997      A. Correa   26
# 446    143076       A. Gómez   33
# 3797   232488      C. Romero   23
# 13832  202811    E. Martínez   28
# 4      224334       M. Acuña   29
# 83     226226    G. Lo Celso   25
# 81     207439     L. Paredes   27
# 2241   170481    20 E. Garay   32
# 70     212616     R. De Paul   27
# 31     205632     L. Ocampos   26
# 1959   201399      M. Icardi   28
# 341    211256  N. Tagliafico   28
# 105    178562      E. Banega   33
# 427    226162     E. Buendía   24
# 1252   215330      J. Correa   26
# 14674  201095   A. Marchesín   33
# 5677   236506      M. Senesi   24
#
#                                                   Photo Nationality  \
# 29     https://cdn.sofifa.com/players/158/023/22_60.png   Argentina
# ...
